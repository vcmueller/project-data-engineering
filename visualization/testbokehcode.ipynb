# %%
import psycopg2
import pandas
from sqlalchemy import create_engine
from bokeh.plotting import figure, output_file, show
from bokeh.tile_providers import CARTODBPOSITRON, get_provider

# %%
alchemyEngine = create_engine('postgresql+psycopg2://etl:etl@localhost/db', pool_recycle=3600);
connection = alchemyEngine.connect();
   
# Get the date of the last temperature loaded
sql = """select * from temperature_level ;
"""
#data = pandas.read_sql(sql, connection)
data = pandas.read_sql_query(sql,con=connection)

# Close database connection
connection.close()

# %%
data
# Out:
#                                  region    country       city  quarter  \
# 0                                Africa    Algeria    Algiers        1
# 1                                Africa    Algeria    Algiers        2
# 2                                Africa    Algeria    Algiers        3
# 3                                Africa    Algeria    Algiers        4
# 4                                Africa      Benin    Cotonou        1
# ...                                 ...        ...        ...      ...
# 1279  South/Central America & Carribean    Uruguay  Montvideo        4
# 1280  South/Central America & Carribean  Venezuela    Caracas        1
# 1281  South/Central America & Carribean  Venezuela    Caracas        2
# 1282  South/Central America & Carribean  Venezuela    Caracas        3
# 1283  South/Central America & Carribean  Venezuela    Caracas        4
#
#       avgtemp  templevel
# 0       11.89     Medium
# 1       19.12       High
# 2       25.28  Very High
# 3       15.72     Medium
# 4       28.60  Very High
# ...       ...        ...
# 1279    18.38       High
# 1280    26.13  Very High
# 1281    27.44  Very High
# 1282    28.13  Very High
# 1283    27.49  Very High
#
# [1284 rows x 6 columns]

# %%
from datetime import date
from random import randint

from bokeh.io import show
from bokeh.models import ColumnDataSource, DataTable, DateFormatter, TableColumn

source = ColumnDataSource(data)

columns = [
        TableColumn(field="region", title="Region"),
        TableColumn(field="country", title="Country"),
        TableColumn(field="city", title="City"),
        TableColumn(field="quarter", title="Quarter"),
        TableColumn(field="avgtemp", title="Temperature"),
        TableColumn(field="templevel", title="Temperature Level"),
    ]
data_table = DataTable(source=source, columns=columns, width=800, height=800)

#output_file("pages/result.html")
show(data_table)

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'lib')))
from lib import dbconfig
os.getcwd()
# Out:
# '/Users/vanessamueller/Library/Mobile Documents/com~apple~CloudDocs/Academic/IU - MSc in AI/Semester 2/Data Engineer/Project - Data Engineering/project-data-engineering/visualization'

# %%
import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 
from parentdir.lib import dbconfig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-0abf0667bbc8> in <module>
#       3 parentdir = os.path.dirname(currentdir)
#       4 sys.path.insert(0, parentdir)
# ----> 5 from parentdir.lib import dbconfig
#
# ModuleNotFoundError: No module named 'parentdir'
